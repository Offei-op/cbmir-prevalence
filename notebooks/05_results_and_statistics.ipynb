# %% [markdown]
# # Summarize results and compare conditions

# %%
from pathlib import Path
import json
import os

# Set this to the extracted repository directory on Kaggle if needed.
REPO_ROOT = Path.cwd()
if not (REPO_ROOT / "configs").exists() and (REPO_ROOT.parent / "configs").exists():
    REPO_ROOT = REPO_ROOT.parent
os.chdir(REPO_ROOT)
import sys
sys.path.insert(0, str(REPO_ROOT / "src"))
config = json.loads((REPO_ROOT / "configs/experiment.json").read_text())
# For Kaggle: config["artifacts_dir"] = "/kaggle/working/cbmir_artifacts"

# %% [markdown]
# Means and SD across gallery samples; paired query-level comparisons after averaging seeds; Holm adjustment; pointwise bootstrap intervals. Read statistical scope in docs/METHODOLOGY_DRAFT.md.

# %%
from cbmir.analysis import run
run(config)

# %%
import pandas as pd
summary = pd.read_csv(Path(config["artifacts_dir"]) / "analysis/headline.csv")
summary.head()

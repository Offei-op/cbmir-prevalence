# %% [markdown]
# # Prepare and audit the data

# %%
from pathlib import Path
import json
import os

# Set this to the extracted repository directory on Kaggle if needed.
REPO_ROOT = Path.cwd()
if not (REPO_ROOT / "configs").exists() and (REPO_ROOT.parent / "configs").exists():
    REPO_ROOT = REPO_ROOT.parent
os.chdir(REPO_ROOT)
import sys
sys.path.insert(0, str(REPO_ROOT / "src"))
config = json.loads((REPO_ROOT / "configs/experiment.json").read_text())
# For Kaggle: config["artifacts_dir"] = "/kaggle/working/cbmir_artifacts"

# %% [markdown]
# Produces frozen training, validation, query and gallery manifests. The original common-pool audit found three conflicting-label duplicate groups. Default behavior stops for review; see `docs/AUDIT.md`. Excluding groups changes the experiment and requires downstream regeneration.

# %%
from cbmir.prepare import run
run(config)

# %%
from cbmir.validation import validate_artifacts, content_audit
validate_artifacts(config["artifacts_dir"], config, check_images=True)
content_audit(config["artifacts_dir"])

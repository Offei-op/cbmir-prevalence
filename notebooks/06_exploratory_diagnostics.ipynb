# %% [markdown]
# # Optional cohort diagnostics

# %%
from pathlib import Path
import json
import os

# Set this to the extracted repository directory on Kaggle if needed.
REPO_ROOT = Path.cwd()
if not (REPO_ROOT / "configs").exists() and (REPO_ROOT.parent / "configs").exists():
    REPO_ROOT = REPO_ROOT.parent
os.chdir(REPO_ROOT)
import sys
sys.path.insert(0, str(REPO_ROOT / "src"))
config = json.loads((REPO_ROOT / "configs/experiment.json").read_text())
# For Kaggle: config["artifacts_dir"] = "/kaggle/working/cbmir_artifacts"

# %% [markdown]
# Tests whether query versus gallery cohort membership can be predicted from embeddings for TB and Pneumothorax. This does not identify a causal source-bias mechanism or diagnose why retrieval fails.

# %%
from cbmir.diagnostics import run
run(config)
